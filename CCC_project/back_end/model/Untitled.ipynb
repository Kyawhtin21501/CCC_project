# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
import joblib

# %%
df = pd.read_csv("../data/project.csv")

# %%
colum = df.colum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/23/dxqwsqmd1w3g02ljvb96m6fm0000gn/T/ipykernel_50203/665506678.py in ?()
# ----> 1 colum = df.colum()
#
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'colum'

# %%
df.head(10)
df_new = df.drop(columns=["Unnamed: 0.3", "Unnamed: 0.2", "Unnamed: 0.1"])

# %%
df_new.head()
# Out:
#          date    weekday  is_festival  guests   sales  \
# 0  2000-01-01   Saturday            0     245  293932
# 1  2000-01-02     Sunday            0     260  311917
# 2  2000-01-03     Monday            0     163  195608
# 3  2000-01-04    Tuesday            0     166  199243
# 4  2000-01-05  Wednesday            0     148  177537
#
#                               assigned_staff  total_staff_level  staff_count  \
# 0      ['Eve', 'Ivy', 'Mia', 'Quinn', 'Bob']                 22            5
# 1  ['Eve', 'Ivy', 'Mia', 'Quinn', 'Charlie']                 23            5
# 2                    ['Eve', 'Ivy', 'David']                 14            3
# 3                    ['Eve', 'Ivy', 'David']                 14            3
# 4                  ['Eve', 'Ivy', 'Charlie']                 13            3
#
#    sale_per_guest  staff_per_guest  ...  month  season Unnamed: 0  \
# 0     1199.722449         0.020408  ...      1  winter     5640.0
# ...
