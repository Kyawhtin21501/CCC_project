# %% [markdown]
# <a href="https://colab.research.google.com/github/Kyawhtin21501/CCC_project/blob/develop/retrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import xgboost as xgb
from sklearn.preprocessing import LabelEncoder
import joblib
data = pd.read_csv("data/user_input.csv")
data.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 12
#       9 data.fillna(data.mean(numeric_only=True), inplace=True)
#      11 #data["date"] = pd.to_datetime(data["date"], errors="coerce")
# ---> 12 data["year"] = data["date"].dt.isocalendar().year
#      13 data["month"] = data["date"].dt.month
#      14 data["day"] = data["date"].dt.day
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'date'

# %%
display(type(data))
# Out:
# pandas.core.frame.DataFrame

# %%
data.head()
# Out:
#         date  is_event   sales  customers  staff_count  \
# 0 2025-07-03      True  210000        156            3
# 1 2025-07-03     False   20000        200            2
# 2 2025-07-08     False  250000        190            3
# 3 2025-07-08     False   25000        250            3
# 4 2025-07-08     False   20000        200            3
#
#                                          staff_names  staff_total_skills  \
# 0  ['Kyaw Htin Hein', 'Yan Shin Shein', 'Kyi Pyar...                  15
# 1               ['Kyaw Htin Hein', 'Yan Shin Shein']                  10
# 2       ['Lisa', 'Kyaw Htin Hein', 'Yan Shin Shein']                  15
# 3  ['Yan Shin Shein', 'Kyaw Htin Hein', 'Kyi Pyar...                  15
# 4               ['Kyaw', 'Kyi Pyar Hlaing', 'Jenie']                   5
#
#    year  month  day  weekday  weekofyear
# 0  2025      7    3        3          27
# 1  2025      7    3        3          27
# 2  2025      7    8        1          28
# 3  2025      7    8        1          28
# 4  2025      7    8        1          28

# %%
data["date"]
# Out:
# 0     2025-07-03
# 1     2025-07-03
# 2     2025-07-08
# 3     2025-07-08
# 4     2025-07-08
#          ...
# 98    2025-08-07
# 99    2025-08-08
# 100   2025-08-15
# 101   2025-08-19
# 102   2025-08-19
# Name: date, Length: 103, dtype: datetime64[ns]

# %%
print(data.isnull().sum())

if data.isnull().sum().sum() > 0:  
    data.dropna(inplace=True)
# Out:
# date                  0
# is_event              0
# sales                 0
# customers             0
# staff_count           0
# staff_names           0
# staff_total_skills    0
# year                  0
# month                 0
# day                   0
# weekday               0
# weekofyear            0
# dtype: int64

# %%
duplicated_data = data[data["date"].duplicated()]

if len(duplicated_data) > 0:
    data.drop_duplicates(subset=["date"], inplace=True)  

data.head(10)
# Out:
#          date  is_event   sales  customers  staff_count  \
# 0  2025-07-03      True  210000        156            3
# 2  2025-07-08     False  250000        190            3
# 5  2025-07-11     False  230000        180            3
# 8  2025-07-12     False  240000        120            2
# 11 2025-07-13     False  129806        231            3
# 12 2025-07-14     False  230000        123            4
# 13 2025-07-16     False  230000        180            3
# 14 2025-07-22     False  250000        250            3
# 15 2025-07-28     False  123123        123            3
# 16 2025-08-01     False  903203        233            5
#
#                                           staff_names  staff_total_skills  \
# 0   ['Kyaw Htin Hein', 'Yan Shin Shein', 'Kyi Pyar...                  15
# 2        ['Lisa', 'Kyaw Htin Hein', 'Yan Shin Shein']                  15
# 5       ['Kyaw Htin Hein', 'Kyi Pyar Hlaing', 'Kyaw']                  10
# 8                                  ['Puppy', 'Jenie']                   4
# 11                         ['Lisa', 'Jenie', 'Puppy']                   9
# 12     ['Aung Aung', 'Kyaw Kyaw', 'Zaw Zaw', 'Ko Ko']                   5
# 13                              ['Yss', 'Kph', 'Khh']                   0
# 14                          ['Kyaw', 'Lisa', 'Jenie']                   5
# 15        ['Yan Shin Shein', 'Kyaw Htin Hein', 'Hir']                  10
# 16  ['Lisa', 'Hir', 'Puppy', 'Kyaw Htin Hein', 'Je...                   5
#
#     year  month  day  weekday  weekofyear
# 0   2025      7    3        3          27
# 2   2025      7    8        1          28
# 5   2025      7   11        4          28
# 8   2025      7   12        5          28
# 11  2025      7   13        6          28
# 12  2025      7   14        0          29
# 13  2025      7   16        2          29
# 14  2025      7   22        1          30
# 15  2025      7   28        0          31
# 16  2025      8    1        4          31
